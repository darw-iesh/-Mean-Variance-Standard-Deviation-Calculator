# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import pandas as pd
import seaborn as sns
import math

# %%
sea_data = pd.read_csv('epa-sea-level.csv')
sea_data.head()
# Out:
#    Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0  1880                  0.000000          -0.952756           0.952756
# 1  1881                  0.220472          -0.732283           1.173228
# 2  1882                 -0.440945          -1.346457           0.464567
# 3  1883                 -0.232283          -1.129921           0.665354
# 4  1884                  0.590551          -0.283465           1.464567
#
#    NOAA Adjusted Sea Level
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
plt.scatter(data=sea_data,x='Year', y='CSIRO Adjusted Sea Level')
plt.show()

# %%
sns.lmplot(data=sea_data, x='Year', y='CSIRO Adjusted Sea Level')
plt.show()

# %%
from scipy.stats import linregress

slope, intercept, r_value, p_value, std_err = linregress(
    sea_data["Year"], sea_data["CSIRO Adjusted Sea Level"]
)

# %%
def draw_plot():
    fig, ax = plt.subplots(figsize=(10, 6))

    # Scatter plot
    ax.scatter(sea_data["Year"], sea_data["CSIRO Adjusted Sea Level"], label="Data")

    # Linear regression on full dataset
    slope, intercept, r_value, p_value, std_err = st.linregress(
        sea_data["Year"], sea_data["CSIRO Adjusted Sea Level"]
    )

    years_full = pd.Series(range(sea_data["Year"].min(), 2051))
    line_full = slope * years_full + intercept

    ax.plot(years_full, line_full, "r", label="Best Fit (All Data)")

# %%
sea_data_2000 = sea_data[sea_data["Year"] >= 2000]

slope2, intercept2, r2, p2, se2 = linregress(
        sea_data_2000["Year"], sea_data_2000["CSIRO Adjusted Sea Level"]
    )

years_2000 = pd.Series(range(2000, 2051))
line_2000 = slope2 * years_2000 + intercept2

fig, ax = plt.subplots(figsize=(10, 6))

sea_data_2000 = sea_data[sea_data["Year"] >= 2000]

slope2, intercept2, r2, p2, se2 = linregress(
    sea_data_2000["Year"], sea_data_2000["CSIRO Adjusted Sea Level"]
)

years_2000 = pd.Series(range(2000, 2051))
line_2000 = slope2 * years_2000 + intercept2

ax.plot(years_2000, line_2000, "green", label="Best Fit (2000+)")
ax.legend()
plt.show()

# %%
ax.set_title("Rise in Sea Level")
ax.set_xlabel("Year")
ax.set_ylabel("Sea Level (inches)")
ax.legend()
plt.tight_layout()
plt.show()

# %%
sea_level_2050 = slope * 2050 + intercept
print(sea_level_2050)
# Out:
# 10.175455257136548
